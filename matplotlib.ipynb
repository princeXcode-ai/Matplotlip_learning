# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Matplotlib Basics

# %%
x  = np.linspace(0,6,12)
x
# Out:
# array([0.        , 0.54545455, 1.09090909, 1.63636364, 2.18181818,
#        2.72727273, 3.27272727, 3.81818182, 4.36363636, 4.90909091,
#        5.45454545, 6.        ])

# %%
y = x**2
y
# Out:
# array([ 0.        ,  0.29752066,  1.19008264,  2.67768595,  4.76033058,
#         7.43801653, 10.7107438 , 14.5785124 , 19.04132231, 24.09917355,
#        29.75206612, 36.        ])

# %%
plt.plot(x,y)
plt.title("Graph of square function")
plt.xlabel("X axis")
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %%
plt.subplot(2,2,2)
plt.plot(y,x)
plt.subplot(2,2,1)
plt.plot(x,x)
plt.subplot(2,2,4)
plt.plot(x,y**2)
plt.subplot(2,2,3)
plt.plot(x,y)

# %% [markdown]
# Object oriented way

# %%
fig = plt.figure(figsize=(6,7),dpi =100)
axis1= fig.add_axes([0.1,0.1,1,1])
axis1.plot(x,y)
axis2 = fig.add_axes([0.3,0.4,.4,.3])
axis2.plot(y,x)

# %% [markdown]
# Types of plot

# %%
plt.scatter(x,y)

# %%
plt.hist(x)
# Out:
# (array([2., 1., 1., 1., 1., 1., 1., 1., 1., 2.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
from random import sample 
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([11., 15.,  9.,  7.,  6.,  8.,  9.,  6., 15., 14.]),
#  array([ 46., 141., 236., 331., 426., 521., 616., 711., 806., 901., 996.]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d27445ae90>,
#   <matplotlib.lines.Line2D at 0x1d27445afd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d27445b110>,
#   <matplotlib.lines.Line2D at 0x1d27445b250>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1d27445ad50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d27445b390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d27445b4d0>],
#  'means': []}

# %%
fig=plt.figure()
ax = fig.add_axes([.1,.1,.8,.8])
ax.plot(x,y)
plt.savefig("basicplot.png")

# %% [markdown]
# Working with image

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread("shiv.jpg")
img
# Out:
# array([[[ 71, 158, 211],
#         [ 71, 158, 211],
#         [ 71, 158, 211],
#         ...,
#         [ 99, 177, 223],
#         [ 99, 177, 223],
#         [ 99, 177, 223]],
#
#        [[ 70, 157, 210],
#         [ 70, 157, 210],
#         [ 70, 157, 210],
#         ...,
#         [ 99, 177, 223],
#         [ 98, 176, 222],
#         [ 98, 176, 222]],
#
#        [[ 69, 156, 209],
#         [ 69, 156, 209],
#         [ 69, 156, 209],
#         ...,
#         [100, 178, 224],
#         [100, 178, 224],
#         [ 99, 177, 223]],
#
#        ...,
#
#        [[228, 194, 148],
#         [231, 197, 151],
#         [233, 199, 153],
#         ...,
#         [162, 124,  87],
#         [168, 130,  94],
#         [170, 131,  98]],
#
#        [[235, 206, 150],
#         [234, 205, 149],
#         [232, 203, 147],
#         ...,
#         [165, 124,  94],
#         [169, 128,  98],
#         [171, 130, 100]],
#
#        [[233, 204, 148],
#         [231, 202, 146],
#         [230, 201, 145],
#         ...,
#         [165, 124,  94],
#         [169, 128,  98],
#         [171, 130, 100]]], shape=(3394, 5092, 3), dtype=uint8)

# %%
plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(5091.5), np.float64(3393.5), np.float64(-0.5))

# %% [markdown]
# optional designing

# %%
plt.plot(x,y,color ="blue")

# %%
xaxis = np.linspace(0,5,11)

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(xaxis, xaxis+1, color="red", linewidth=0.25)
ax.plot(xaxis, xaxis+2, color="red", linewidth=0.50)
ax.plot(xaxis, xaxis+3, color="red", linewidth=1.00)
ax.plot(xaxis, xaxis+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(xaxis, xaxis+5, color="green", lw=3, linestyle='-')
ax.plot(xaxis, xaxis+6, color="green", lw=3, ls='-.')
ax.plot(xaxis, xaxis+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(xaxis, xaxis+8, color="black", lw=1.50)
line.set_dashes([5, 50, 15, 50]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(xaxis, xaxis+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(xaxis, xaxis+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(xaxis, xaxis+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(xaxis, xaxis+12, color="blue", lw=3, ls='--', marker='1')
ax.plot(xaxis, xaxis+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(xaxis, xaxis+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(xaxis, xaxis+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(xaxis, xaxis+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");
